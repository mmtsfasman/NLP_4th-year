# %% [markdown]
# ## Задание 1
#
# “тематический” корпус -  Отзывы о ресторанах: малый корпус
# контрастный корпус (reference corpus) - новостной корпус https://nlp4year.wikispaces.com/file/view/news.txt/610208227/news.txt
#
# избирательная кампания
#
# - корпус 1, корпус 2 (или хотя бы примеры текстов из обоих корпусов)
# - код
# - отчет:
#
#
# либо обработать корпуса в Python или NLTK.
#
#
# частотность
#
# weirdness loglikelyhood

# %% [markdown]
# ### Отчет
# #### 1) характеристики исследуемого (тематического) корпуса:
# - (1) признаки “тематического” корпуса - жанр / тематику (любую другую характеристику, по которой Вы отбирали корпус):
# “тематический” корпус - Отзывы о ресторанах: малый корпус контрастный
#
# - (2) источник текстов:
# "Отзывы о ресторанах: малый корпус контрастный" с сайта программы из раздела resources
#
# - (3) объем корпуса:
# 13333 словоформы (без стопслов)
#
# - (4) параметры предобработки:
# полностью лемматизированный, убраны стопслова (стопслова взяты отсюда: https://github.com/stopwords-iso/stopwords-ru/blob/master/stopwords-ru.json)
#
# - (5) подвыборку, которая рассматривалась, если вы брали подвыборку (например, только существительные…, контексты длиной 5 слов...)
# без стопслов
#
# #### 2) характеристики контрастного корпуса (жанр/тематику…, объем, источник, доп. параметры)
# корпус (reference corpus) - новостной корпус https://nlp4year.wikispaces.com/file/view/news.txt/610208227/news.txt
#
# объем - 103794 словоформы (без стопслов)
#
# #### 3) Для второго метода укажите формулу, источник - откуда Вы взяли формулу
# loglikelyhood - http://ucrel.lancs.ac.uk/llwizard.html
# weirdness - презентация с пары
#
# #### 4) Заполните таблицу 1:
#  - укажите в таблице данные для топ 10 тематичных по LogLikelihood и для 10 - находящихся внизу упорядоченного по убыванию значения LogLikelihood списка
# (Таблица составлена полностью автоматически, см. в следующей клетке)
#
#
# #### 5) Напишите комментарии: насколько точен оказался результат применения весов
# Weirdness выделил другие слова, и оказался менее точным, чем LogLikelihood (больше экспрессивных слов попало сюда):
#
#  (ресторан', 2203.082727068177),
#  ('меню', 832.9676741918549),
#  ('еда', 716.1965049126228),
#  ('заведение', 700.6270156753919),
#  ('понравиться', 595.5329633240831),
#  ('блюдо', 529.3626340658517),
#  ('порция', 435.94569864246614),
#  ('отличный', 365.8829970749269),
#  ('заказывать', 358.0982524563114),
#  ('впечатление', 217.97284932123307),
#  ('внимательный', 186.8338708467712),
#  ('вино', 147.91014775369385)
#
# Мусора не очень много ни там ни там, возможно потому что я удаляла стоп слова. Из общеупотребительного только "понравиться" понучило слишком высокую оценку. Это, наверное, из-за того, что новостной корпус не содержит экспрессивных и эмоциональных слов в силу жанра. Все низкие по рангу слова вполне можно назвать общеупотребительными - в этом ошибок не было.
#
# Оцените точность и полноту:
# процент слов в списке топ10, совпавших с моим - 90%,
# процент слов из моего списка, не попавших в топ 10 -  20% (мне показалось, что почти все слова учтены, но не было никаких глаголов еды - есть, кушать и т.п.).

# %%
pandas.DataFrame(data = data)
# Out:
#             word                  Тип  CountSpecC  CountRefC  LogLikelihood  \
# 0       ресторан         тематическое    0.021226   0.000010   1.216875e+03
# 1    понравиться         тематическое    0.011475   0.000019   6.440513e+02
# 2     заказывать         тематическое    0.010350   0.000029   5.714411e+02
# 3          блюдо         тематическое    0.010200   0.000019   5.706366e+02
# 4           меню         тематическое    0.008025   0.000010   4.539123e+02
# 5            еда         тематическое    0.006900   0.000010   3.890224e+02
# 6      заведение         тематическое    0.006750   0.000010   3.803740e+02
# 7      приносить         тематическое    0.008475   0.000222   3.730411e+02
# 8   обслуживание         тематическое    0.008325   0.000241   3.586696e+02
# 9            зал         тематическое    0.006450   0.000067   3.257777e+02
# 10        порция         тематическое    0.004200   0.000010   2.335511e+02
# 11         центр  общеупотребительное    0.001050   0.001050   1.924712e-07
# 12         масса  общеупотребительное    0.000075   0.000077   6.659864e-04
# 13    продлиться  общеупотребительное    0.000075   0.000077   6.659864e-04
# 14       команда  общеупотребительное    0.000075   0.000077   6.659864e-04
# 15       богатый  общеупотребительное    0.000075   0.000077   6.659864e-04
# 16       сдавать  общеупотребительное    0.000075   0.000077   6.659864e-04
# 17   критиковать  общеупотребительное    0.000075   0.000077   6.659864e-04
# 18        точный  общеупотребительное    0.000075   0.000077   6.659864e-04
# 19        летать  общеупотребительное    0.000075   0.000077   6.659864e-04
# 20        спустя  общеупотребительное    0.000075   0.000077   6.659864e-04
# 21         пусть  общеупотребительное    0.000075   0.000077   6.659864e-04
#
#     Ранг loglikelihood    Weirdness  Ранг weirdness
# 0                    0  2203.082727               0
# 1                    1   595.532963               4
# 2                    2   358.098252               8
# 3                    3   529.362634               5
# 4                    4   832.967674               1
# 5                    5   716.196505               2
# 6                    6   700.627016               3
# 7                    7    38.246789              86
# 8                    8    34.564266              89
# 9                    9    95.641148              22
# 10                  10   435.945699               6
# 11                1345     0.999875             951
# 12                1334     0.973093             954
# 13                1335     0.973093             956
# 14                1336     0.973093             959
# 15                1337     0.973093             960
# 16                1338     0.973093             963
# 17                1339     0.973093             964
# 18                1340     0.973093             966
# 19                1341     0.973093             967
# 20                1342     0.973093             968
# 21                1343     0.973093             970

# %%
from pymystem3 import Mystem
import re
import numpy as np
import operator
import pandas
import collections

stop_words = ["а","алло","без","белый","близко","более","больше","большой","будем","будет","будете","будешь","будто","буду","будут","будь","бы","бывает","бывь","был","была","были","было","быть","в","важная","важное","важные","важный","вам","вами","вас","ваш","ваша","ваше","ваши","вверх","вдали","вдруг","ведь","везде","вернуться","весь","вечер","взгляд","взять","вид","видеть","вместе","вниз","внизу","во","вода","война","вокруг","вон","вообще","вопрос","восемнадцатый","восемнадцать","восемь","восьмой","вот","впрочем","времени","время","все","всегда","всего","всем","всеми","всему","всех","всею","всю","всюду","вся","всё","второй","вы","выйти","г","где","главный","глаз","говорил","говорит","говорить","год","года","году","голова","голос","город","да","давать","давно","даже","далекий","далеко","дальше","даром","дать","два","двадцатый","двадцать","две","двенадцатый","двенадцать","дверь","двух","девятнадцатый","девятнадцать","девятый","девять","действительно","дел","делать","дело","день","деньги","десятый","десять","для","до","довольно","долго","должно","должный","дом","дорога","друг","другая","другие","других","друго","другое","другой","думать","душа","е","его","ее","ей","ему","если","есть","еще","ещё","ею","её","ж","ждать","же","жена","женщина","жизнь","жить","за","занят","занята","занято","заняты","затем","зато","зачем","здесь","земля","знать","значит","значить","и","идти","из","или","им","именно","иметь","ими","имя","иногда","их","к","каждая","каждое","каждые","каждый","кажется","казаться","как","какая","какой","кем","книга","когда","кого","ком","комната","кому","конец","конечно","которая","которого","которой","которые","который","которых","кроме","кругом","кто","куда","лежать","лет","ли","лицо","лишь","лучше","любить","люди","м","маленький","мало","мать","машина","между","меля","менее","меньше","меня","место","миллионов","мимо","минута","мир","мира","мне","много","многочисленная","многочисленное","многочисленные","многочисленный","мной","мною","мог","могут","мож","может","можно","можхо","мои","мой","мор","москва","мочь","моя","моё","мы","на","наверху","над","надо","назад","наиболее","найти","наконец","нам","нами","народ","нас","начала","начать","наш","наша","наше","наши","не","него","недавно","недалеко","нее","ней","некоторый","нельзя","нем","немного","нему","непрерывно","нередко","несколько","нет","нею","неё","ни","нибудь","ниже","низко","никакой","никогда","никто","никуда","ними","них","ничего","ничто","но","новый","нога","ночь","ну","нужно","нужный","нх","о","об","оба","обычно","один","одиннадцатый","одиннадцать","однажды","однако","одного","одной","оказаться","окно","около","он","она","они","оно","опять","особенно","остаться","от","ответить","отец","отовсюду","отсюда","очень","первый","перед","писать","плечо","по","под","подумать","пожалуйста","позже","пойти","пока","пол","получить","помнить","понимать","понять","пор","пора","после","последний","посмотреть","посреди","потом","потому","почему","почти","правда","прекрасно","при","про","просто","против","процентов","пятнадцатый","пятнадцать","пятый","пять","работа","работать","раз","разве","рано","раньше","ребенок","решить","россия","рука","русский","ряд","рядом","с","сам","сама","сами","самим","самими","самих","само","самого","самой","самом","самому","саму","самый","свет","свое","своего","своей","свои","своих","свой","свою","сделать","сеаой","себе","себя","сегодня","седьмой","сейчас","семнадцатый","семнадцать","семь","сидеть","сила","сих","сказал","сказала","сказать","сколько","слишком","слово","случай","смотреть","сначала","снова","со","собой","собою","советский","совсем","спасибо","спросить","сразу","стал","старый","стать","стол","сторона","стоять","страна","суть","считать","т","та","так","такая","также","таки","такие","такое","такой","там","твой","твоя","твоё","те","тебе","тебя","тем","теми","теперь","тех","то","тобой","тобою","товарищ","тогда","того","тоже","только","том","тому","тот","тою","третий","три","тринадцатый","тринадцать","ту","туда","тут","ты","тысяч","у","увидеть","уж","уже","улица","уметь","утро","хороший","хорошо","хотеть","хоть","хотя","хочешь","час","часто","часть","чаще","чего","человек","чем","чему","через","четвертый","четыре","четырнадцатый","четырнадцать","что","чтоб","чтобы","чуть","шестнадцатый","шестнадцать","шестой","шесть","эта","эти","этим","этими","этих","это","этого","этой","этом","этому","этот","эту","я"]

m = Mystem()

# %%
#функция обработки текста
def text_to_words(filename, stop_words):
    with open(filename) as f:
        text = f.read()
        all_words = m.lemmatize(text)

    all_words_clean = []
    for w in all_words:
        if w in stop_words or re.search('[А-Яа-я]', w) == None:
            pass
        else:
            all_words_clean.append(w)
    
    return all_words_clean

# %%
def weirdness(Nd, Nl, cd, cl):
    '''Nd = total Spec
        Nl = total Ref
        cd = frequency word Spec
        cl = frequency word Ref
    '''
    return ((cd/Nd)/(cl/Nl))

# %%
def loglikelihood(a, b, c, d):
    ''' 
    a = frequency word Spec
    b = frequency word Ref
    c = total Spec
    d = total Ref   
    '''
    E1 = (c*(a+b))/(c+d)
    E2 = (d*(a+b))/(c+d)
    ln1 = np.log(a/E1)
    ln2 = np.log(b/E2)
    return (2*((a*ln1) + (b*ln2)))

# %%
def word_frequency(text):            
    #функция, подсчитывающая частоту каждого слова в корпусе text
    frequency = {}
    for word in text:
        if word in frequency:
            frequency[word] += 1
        else:
            frequency[word] = 1 
    return frequency

# %%
Ref = text_to_words('news.txt', stop_words)
Spec = text_to_words('reviews_test.txt', stop_words)
frequencyRef = word_frequency(Ref)
frequencySpec = word_frequency(Spec)

loglikelihood_total = {}
weirdness_total = {}
for word in set(Spec):
    if word in frequencyRef:
        loglikelihood_total[word] = loglikelihood(frequencySpec[word], frequencyRef[word], len(Spec), len(Ref))
        weirdness_total[word] = weirdness(len(Spec), len(Ref), frequencySpec[word], frequencyRef[word])

# %%
#сортировка по возрастанию лог лайклихуд и weirdness
sorted_by_loglikelihood = sorted(loglikelihood_total.items(), key=lambda x: float(x[1]), reverse = True)
sorted_by_weirdness = sorted(weirdness_total.items(), key=lambda x: float(x[1]), reverse = True)

# %%
sorted_by_weirdness
# Out:
# [('ресторан', 2203.082727068177),
#  ('меню', 832.9676741918549),
#  ('еда', 716.1965049126228),
#  ('заведение', 700.6270156753919),
#  ('понравиться', 595.5329633240831),
#  ('блюдо', 529.3626340658517),
#  ('порция', 435.94569864246614),
#  ('отличный', 365.8829970749269),
#  ('заказывать', 358.0982524563114),
#  ('впечатление', 217.97284932123307),
#  ('внимательный', 186.8338708467712),
#  ('вино', 147.91014775369385),
#  ('отлично', 132.34065851646292),
#  ('рождение', 128.4482862071552),
#  ('музыка', 127.15082877071926),
#  ('живой', 124.55591389784745),
#  ('вежливый', 116.77116927923198),
#  ('этаж', 108.98642466061654),
#  ('теплый', 108.98642466061654),
#  ('праздник', 105.09405235130879),
#  ('р', 101.20168004200106),
#  ('горячий', 98.60676516912923),
#  ('зал', 95.64114817156143),
#  ('неплохой', 93.4169354233856),
#  ('советовать', 93.4169354233856),
#  ('показываться', 85.63219080477012),
#  ('коктейль', 85.63219080477012),
#  ('радовать', 85.63219080477012),
#  ('случайно', 77.84744618615466),
#  ('пить', 77.84744618615466),
#  ('хлеб', 77.84744618615466),
#  ('удобно', 77.84744618615466),
#  ('бутылка', 77.84744618615466),
#  ('сыр', 77.84744618615466),
#  ('хотеться', 77.84744618615466),
#  ('попробовать', 75.90126003150078),
#  ('паста', 75.25253131328283),
#  ('зайти', 73.17659941498538),
#  ('удовольствие', 70.0627015675392),
#  ('холодный', 70.0627015675392),
#  ('прибор', 70.0627015675392),
#  ('приготовление', 70.0627015675392),
#  ('восторг', 66.17032925823146),
#  ('посещение', 66.17032925823146),
#  ('мясной', 62.27795694892372),
#  ('сходить', 62.27795694892372),
#  ('качественный', 62.27795694892372),
#  ('ходить', 56.05016125403135),
#  ('стойка', 54.49321233030827),
#  ('тихий', 54.49321233030827),
#  ('вежливо', 54.49321233030827),
#  ('качественно', 54.49321233030827),
#  ('поражать', 54.49321233030827),
#  ('встречать', 54.49321233030825),
#  ('обязательно', 52.547026175654395),
#  ('достойный', 50.60084002100053),
#  ('съедать', 50.60084002100053),
#  ('удивлять', 49.82236555913897),
#  ('захотеться', 46.7084677116928),
#  ('ехать', 46.7084677116928),
#  ('тихо', 46.7084677116928),
#  ('родитель', 46.7084677116928),
#  ('питер', 46.7084677116928),
#  ('пустой', 46.7084677116928),
#  ('пробовать', 46.7084677116928),
#  ('подарок', 46.7084677116928),
#  ('фото', 46.7084677116928),
#  ('особенный', 46.7084677116928),
#  ('спрашивать', 46.70846771169279),
#  ('сервис', 45.411010275256885),
#  ('удобный', 44.762281557038925),
#  ('сок', 42.81609540238506),
#  ('свинина', 42.81609540238506),
#  ('посоветовать', 41.51863796594915),
#  ('заказ', 39.57245181129529),
#  ('спокойный', 38.92372309307733),
#  ('жаль', 38.92372309307733),
#  ('идеально', 38.92372309307733),
#  ('сытый', 38.92372309307733),
#  ('честно', 38.92372309307733),
#  ('пообщаться', 38.92372309307733),
#  ('майкл', 38.92372309307733),
#  ('ужасный', 38.92372309307733),
#  ('грузинский', 38.92372309307733),
#  ('адекватный', 38.92372309307733),
#  ('свежий', 38.92372309307732),
#  ('приносить', 38.24678877841511),
#  ('бывать', 35.0313507837696),
#  ('стиль', 35.0313507837696),
#  ('обслуживание', 34.56426610665267),
#  ('нравиться', 34.47529759672563),
#  ('посещать', 33.26209064317517),
#  ('вход', 32.69592739818495),
#  ('вовремя', 31.13897847446186),
#  ('заправка', 31.13897847446186),
#  ('сырный', 31.13897847446186),
#  ('посадить', 31.13897847446186),
#  ('частый', 31.13897847446186),
#  ('располагаться', 31.13897847446186),
#  ('поблагодарить', 31.13897847446186),
#  ('благодарность', 31.13897847446186),
#  ('странно', 31.13897847446186),
#  ('волшебный', 31.13897847446186),
#  ('ценник', 31.13897847446186),
#  ('благодарный', 31.13897847446186),
#  ('удивляться', 31.13897847446186),
#  ('приличный', 31.13897847446186),
#  ('расслабляться', 31.13897847446186),
#  ('коллектив', 31.13897847446186),
#  ('расстраиваться', 31.13897847446186),
#  ('мясо', 29.192792319807996),
#  ('подходить', 28.803555088877218),
#  ('минус', 28.54406360159004),
#  ('оригинальный', 27.246606165154134),
#  ('добрый', 27.246606165154134),
#  ('обслуживать', 27.246606165154127),
#  ('что-то', 26.690552978110166),
#  ('скидка', 25.300420010500265),
#  ('персонал', 25.08417710442761),
#  ('висок', 23.3542338558464),
#  ('сухой', 23.3542338558464),
#  ('бесплатный', 23.3542338558464),
#  ('тесто', 23.3542338558464),
#  ('услышать', 23.3542338558464),
#  ('домой', 23.3542338558464),
#  ('нормально', 23.3542338558464),
#  ('выдерживать', 23.3542338558464),
#  ('полно', 23.3542338558464),
#  ('грязный', 23.3542338558464),
#  ('обрадоваться', 23.3542338558464),
#  ('академический', 23.3542338558464),
#  ('разочаровываться', 23.3542338558464),
#  ('футбольный', 23.3542338558464),
#  ('капуста', 23.3542338558464),
#  ('сочетание', 23.3542338558464),
#  ('бронировать', 23.3542338558464),
#  ('молодой', 22.57575939398485),
#  ('стена', 21.40804770119253),
#  ('светлый', 21.40804770119253),
#  ('везти', 20.759318982974573),
#  ('мелочь', 20.759318982974573),
#  ('садиться', 20.24033600840021),
#  ('ощущение', 19.461861546538664),
#  ('эмоция', 19.461861546538664),
#  ('интересно', 19.461861546538664),
#  ('общение', 19.461861546538664),
#  ('главное', 19.46186154653866),
#  ('огромный', 19.162448291976528),
#  ('обстановка', 18.349755172450738),
#  ('оформление', 18.164404110102755),
#  ('мужчина', 18.164404110102755),
#  ('курица', 18.164404110102755),
#  ('заранее', 18.164404110102755),
#  ('нигде', 18.164404110102755),
#  ('кстати', 17.5156753918848),
#  ('всякий', 17.5156753918848),
#  ('располагать', 17.5156753918848),
#  ('детский', 17.126438160954024),
#  ('молодец', 16.866946673666842),
#  ('быстро', 16.64324711566065),
#  ('масло', 15.56948923723093),
#  ('ножка', 15.56948923723093),
#  ('подробно', 15.56948923723093),
#  ('специально', 15.56948923723093),
#  ('классический', 15.56948923723093),
#  ('царить', 15.56948923723093),
#  ('крутить', 15.56948923723093),
#  ('марат', 15.56948923723093),
#  ('картофель', 15.56948923723093),
#  ('шутка', 15.56948923723093),
#  ('маргарита', 15.56948923723093),
#  ('продумывать', 15.56948923723093),
#  ('зарезервировать', 15.56948923723093),
#  ('сорт', 15.56948923723093),
#  ('по-моему', 15.56948923723093),
#  ('окружать', 15.56948923723093),
#  ('дочь', 15.56948923723093),
#  ('планета', 15.56948923723093),
#  ('уместный', 15.56948923723093),
#  ('ползти', 15.56948923723093),
#  ('экран', 15.56948923723093),
#  ('проходной', 15.56948923723093),
#  ('чувство', 15.56948923723093),
#  ('удачно', 15.56948923723093),
#  ('артем', 15.56948923723093),
#  ('цветок', 15.56948923723093),
#  ('чудо', 15.56948923723093),
#  ('шкаф', 15.56948923723093),
#  ('куриный', 15.56948923723093),
#  ('буквально', 15.56948923723093),
#  ('здоровый', 15.56948923723093),
#  ('макароны', 15.56948923723093),
#  ('пара', 15.56948923723093),
#  ('нюанс', 15.56948923723093),
#  ('божественный', 15.56948923723093),
#  ('тянуть', 15.56948923723093),
#  ('сюрприз', 15.56948923723093),
#  ('пожалуй', 15.56948923723093),
#  ('выслушивать', 15.56948923723093),
#  ('испортить', 15.56948923723093),
#  ('воспоминание', 15.56948923723093),
#  ('выкладывать', 15.56948923723093),
#  ('кондитерский', 15.56948923723093),
#  ('отдельно', 15.56948923723093),
#  ('морепродукт', 15.56948923723093),
#  ('случайный', 15.56948923723093),
#  ('прага', 15.56948923723093),
#  ('рекомендовать', 15.082942698567466),
#  ('отзыв', 14.828084987838983),
#  ('итальянский', 14.457382863143007),
#  ('выбор', 14.27203180079502),
#  ('выходной', 14.012540313507838),
#  ('сожаление', 13.901329676099044),
#  ('выбирать', 13.800229096636507),
#  ('странный', 13.623303082577067),
#  ('красный', 13.623303082577067),
#  ('абсолютно', 13.345276489055083),
#  ('наверное', 13.345276489055083),
#  ('четко', 12.97457436435911),
#  ('настолько', 12.97457436435911),
#  ('двое', 12.97457436435911),
#  ('удача', 12.97457436435911),
#  ('настроение', 12.97457436435911),
#  ('рыба', 12.650210005250132),
#  ('готовить', 11.9060800049413),
#  ('приходить', 11.846350506588752),
#  ('пасть', 11.6771169279232),
#  ('возле', 11.6771169279232),
#  ('почувствовать', 11.6771169279232),
#  ('уносить', 11.6771169279232),
#  ('мария', 11.6771169279232),
#  ('рыбный', 11.6771169279232),
#  ('дважды', 11.6771169279232),
#  ('радость', 11.6771169279232),
#  ('супруга', 11.6771169279232),
#  ('чувствовать', 11.6771169279232),
#  ('страшный', 11.6771169279232),
#  ('сдача', 11.6771169279232),
#  ('песня', 11.6771169279232),
#  ('подсказывать', 11.6771169279232),
#  ('слава', 11.6771169279232),
#  ('радио', 11.6771169279232),
#  ('неожиданно', 11.6771169279232),
#  ('тепло', 11.6771169279232),
#  ('кусок', 11.6771169279232),
#  ('порекомендовать', 11.6771169279232),
#  ('бесплатно', 11.6771169279232),
#  ('пропадать', 11.6771169279232),
#  ('как-то', 11.677116927923198),
#  ('видно', 11.244631115777896),
#  ('забывать', 11.121063740879237),
#  ('провожать', 10.898642466061652),
#  ('открываться', 10.898642466061652),
#  ('убирать', 10.898642466061652),
#  ('мягкий', 10.704023850596265),
#  ('оформлять', 10.704023850596265),
#  ('приезжать', 10.379659491487287),
#  ('подождать', 10.379659491487287),
#  ('лишний', 10.379659491487287),
#  ('чисто', 10.379659491487287),
#  ('разнообразный', 10.379659491487287),
#  ('неприятный', 10.379659491487287),
#  ('где-то', 10.379659491487287),
#  ('интересный', 10.074375388796485),
#  ('аппетит', 9.730930773269332),
#  ('аккуратно', 9.730930773269332),
#  ('нормальный', 9.341693542338557),
#  ('желать', 9.341693542338557),
#  ('успевать', 8.982397636863997),
#  ('целый', 8.982397636863997),
#  ('приемлемый', 8.896850992703389),
#  ('читать', 8.896850992703389),
#  ('мешать', 8.649716242906074),
#  ('особо', 8.563219080477012),
#  ('оставлять', 8.538107001062123),
#  ('грамотно', 7.784744618615465),
#  ('учиться', 7.784744618615465),
#  ('чистота', 7.784744618615465),
#  ('расписывать', 7.784744618615465),
#  ('подмечать', 7.784744618615465),
#  ('уважать', 7.784744618615465),
#  ('отнимать', 7.784744618615465),
#  ('солнце', 7.784744618615465),
#  ('поговорить', 7.784744618615465),
#  ('печально', 7.784744618615465),
#  ('охлаждать', 7.784744618615465),
#  ('что-нибудь', 7.784744618615465),
#  ('беременность', 7.784744618615465),
#  ('коробка', 7.784744618615465),
#  ('добро', 7.784744618615465),
#  ('угадывать', 7.784744618615465),
#  ('поделиться', 7.784744618615465),
#  ('собственно', 7.784744618615465),
#  ('финский', 7.784744618615465),
#  ('диск', 7.784744618615465),
#  ('фокус', 7.784744618615465),
#  ('портить', 7.784744618615465),
#  ('фишка', 7.784744618615465),
#  ('магазин', 7.784744618615465),
#  ('слагать', 7.784744618615465),
#  ('упоминание', 7.784744618615465),
#  ('несоответствие', 7.784744618615465),
#  ('неплохо', 7.784744618615465),
#  ('смешаться', 7.784744618615465),
#  ('предшественник', 7.784744618615465),
#  ('излишек', 7.784744618615465),
#  ('опять-таки', 7.784744618615465),
#  ('гореть', 7.784744618615465),
#  ('обменяться', 7.784744618615465),
#  ('сопровождение', 7.784744618615465),
#  ('терпимый', 7.784744618615465),
#  ('прикладывать', 7.784744618615465),
#  ('шестеро', 7.784744618615465),
#  ('сорок', 7.784744618615465),
#  ('острый', 7.784744618615465),
#  ('рисование', 7.784744618615465),
#  ('компьютер', 7.784744618615465),
#  ('сцена', 7.784744618615465),
#  ('долгожданный', 7.784744618615465),
#  ('положительный', 7.784744618615465),
#  ('недочет', 7.784744618615465),
#  ('занятый', 7.784744618615465),
#  ('окраина', 7.784744618615465),
#  ('неравнодушный', 7.784744618615465),
#  ('церемония', 7.784744618615465),
#  ('сестра', 7.784744618615465),
#  ('касса', 7.784744618615465),
#  ('порадоваться', 7.784744618615465),
#  ('безразличный', 7.784744618615465),
#  ('закрываться', 7.784744618615465),
#  ('др', 7.784744618615465),
#  ('настораживать', 7.784744618615465),
#  ('профессионально', 7.784744618615465),
#  ('бросаться', 7.784744618615465),
#  ('поднебесный', 7.784744618615465),
#  ('причал', 7.784744618615465),
#  ('чайка', 7.784744618615465),
#  ('непременно', 7.784744618615465),
#  ('позаботиться', 7.784744618615465),
#  ('тронуть', 7.784744618615465),
#  ('плотный', 7.784744618615465),
#  ('хозяин', 7.784744618615465),
#  ('колбаса', 7.784744618615465),
#  ('заинтересованность', 7.784744618615465),
#  ('шоколад', 7.784744618615465),
#  ('одновременный', 7.784744618615465),
#  ('мороз', 7.784744618615465),
#  ('профессионал', 7.784744618615465),
#  ('медленный', 7.784744618615465),
#  ('неподалеку', 7.784744618615465),
#  ('спокойно', 7.784744618615465),
#  ('танцевать', 7.784744618615465),
#  ('семейный', 7.784744618615465),
#  ('метрополь', 7.784744618615465),
#  ('летие', 7.784744618615465),
#  ('делить', 7.784744618615465),
#  ('оперативно', 7.784744618615465),
#  ('накладывать', 7.784744618615465),
#  ('дача', 7.784744618615465),
#  ('карточка', 7.784744618615465),
#  ('кто-то', 7.784744618615465),
#  ('редко', 7.784744618615465),
#  ('повезти', 7.784744618615465),
#  ('плавно', 7.784744618615465),
#  ('залив', 7.784744618615465),
#  ('поход', 7.784744618615465),
#  ('тверской', 7.784744618615465),
#  ('стоящий', 7.784744618615465),
#  ('теснота', 7.784744618615465),
#  ('сочетаться', 7.784744618615465),
#  ('картошка', 7.784744618615465),
#  ('ломоносов', 7.784744618615465),
#  ('билл', 7.784744618615465),
#  ('удаленный', 7.784744618615465),
#  ('наполовину', 7.784744618615465),
#  ('твердый', 7.784744618615465),
#  ('глядеть', 7.784744618615465),
#  ('неприятно', 7.784744618615465),
#  ('разваливаться', 7.784744618615465),
#  ('переполнять', 7.784744618615465),
#  ('бог', 7.784744618615465),
#  ('похоже', 7.784744618615465),
#  ('цвет', 7.784744618615465),
#  ('идеал', 7.784744618615465),
#  ('нежели', 7.784744618615465),
#  ('театр', 7.784744618615465),
#  ('умирать', 7.784744618615465),
#  ('поверять', 7.784744618615465),
#  ('моментально', 7.784744618615465),
#  ('толк', 7.784744618615465),
#  ('дерево', 7.784744618615465),
#  ('одинаковый', 7.784744618615465),
#  ('убеждаться', 7.784744618615465),
#  ('пища', 7.784744618615465),
#  ('выносить', 7.784744618615465),
#  ('модный', 7.784744618615465),
#  ('умеренный', 7.784744618615465),
#  ('несомненно', 7.784744618615465),
#  ('кое-что', 7.784744618615465),
#  ('доверять', 7.784744618615465),
#  ('доска', 7.784744618615465),
#  ('разбирать', 7.784744618615465),
#  ('накладка', 7.784744618615465),
#  ('аппетитный', 7.784744618615465),
#  ('подниматься', 7.784744618615465),
#  ('забота', 7.784744618615465),
#  ('подушка', 7.784744618615465),
#  ('испугать', 7.784744618615465),
#  ('неполный', 7.784744618615465),
#  ('близость', 7.784744618615465),
#  ('равнодушный', 7.784744618615465),
#  ('что-либо', 7.784744618615465),
#  ('палец', 7.784744618615465),
#  ('простор', 7.784744618615465),
#  ('табачный', 7.784744618615465),
#  ('ширма', 7.784744618615465),
#  ('черт', 7.784744618615465),
#  ('некрасов', 7.784744618615465),
#  ('негатив', 7.784744618615465),
#  ('усовершенствовать', 7.784744618615465),
#  ('империя', 7.784744618615465),
#  ('мысль', 7.784744618615465),
#  ('восхищение', 7.784744618615465),
#  ('искренне', 7.784744618615465),
#  ('фотография', 7.784744618615465),
#  ('полезно', 7.784744618615465),
#  ('повесить', 7.784744618615465),
#  ('банальный', 7.784744618615465),
#  ('записывать', 7.784744618615465),
#  ('детство', 7.784744618615465),
#  ('двор', 7.784744618615465),
#  ('размышлять', 7.784744618615465),
#  ('поинтересоваться', 7.784744618615465),
#  ('составление', 7.784744618615465),
#  ('кондитер', 7.784744618615465),
#  ('почитать', 7.784744618615465),
#  ('норвежский', 7.784744618615465),
#  ('мерка', 7.784744618615465),
#  ('отрабатывать', 7.784744618615465),
#  ('строчка', 7.784744618615465),
#  ('бесспорно', 7.784744618615465),
#  ('валиться', 7.784744618615465),
#  ('индикатор', 7.784744618615465),
#  ('нечего', 7.784744618615465),
#  ('дружественный', 7.784744618615465),
#  ('отправляться', 7.784744618615465),
#  ('зря', 7.784744618615465),
#  ('мужской', 7.784744618615465),
#  ('брать', 7.352258806470162),
#  ('дорогой', 7.006270156753919),
#  ('лично', 6.919772994324858),
#  ('видимо', 6.617032925823145),
#  ('достаточно', 6.430875989291037),
#  ('японский', 6.430875989291037),
#  ('прямо', 6.369336506139926),
#  ('играть', 6.369336506139926),
#  ('какой-нибудь', 6.227795694892372),
#  ('далее', 6.227795694892372),
#  ('молочный', 6.227795694892372),
#  ('высоко', 6.054801370034252),
#  ('карта', 6.054801370034252),
#  ('подача', 6.054801370034252),
#  ('дорого', 6.054801370034252),
#  ('свободный', 6.015484478021041),
#  ('весьма', 5.988265091242666),
#  ('полчаса', 5.8385584639616),
#  ('справляться', 5.8385584639616),
#  ('остальное', 5.8385584639616),
#  ('подводить', 5.8385584639616),
#  ('идеальный', 5.8385584639616),
#  ('недовольный', 5.8385584639616),
#  ('беседа', 5.8385584639616),
#  ('уходить', 5.708812720318008),
#  ('недостаток', 5.560531870439618),
#  ('единственный', 5.470361083351408),
#  ('совершенно', 5.449321233030826),
#  ('помогать', 5.389438582118399),
#  ('профессиональный', 5.189829745743643),
#  ('телевизор', 5.189829745743643),
#  ('превосходить', 5.189829745743643),
#  ('поменяться', 5.189829745743643),
#  ('клуб', 5.189829745743643),
#  ('вроде', 5.189829745743643),
#  ('надоедать', 5.189829745743643),
#  ('останавливаться', 5.189829745743643),
#  ('аквариум', 5.189829745743643),
#  ('предпочтение', 5.189829745743643),
#  ('освобождаться', 5.189829745743643),
#  ('внимание', 4.9822365559138975),
#  ('готовиться', 4.953928393664388),
#  ('легкий', 4.953928393664388),
#  ('получаться', 4.916680811757136),
#  ('держать', 4.865465386634666),
#  ('ради', 4.865465386634666),
#  ('слышать', 4.67084677116928),
#  ('громко', 4.670846771169279),
#  ('дешево', 4.670846771169279),
#  ('дождаться', 4.670846771169279),
#  ('анна', 4.670846771169279),
#  ('одежда', 4.670846771169279),
#  ('комфортный', 4.670846771169279),
#  ('оставаться', 4.6109641202568525),
#  ('задержка', 4.448425496351694),
#  ('сравнивать', 4.448425496351694),
#  ('небольшой', 4.3913944002446215),
#  ('стоить', 4.3913944002446215),
#  ('помещение', 4.3789188479712),
#  ('хватить', 4.324858121453037),
#  ('соотношение', 4.324858121453037),
#  ('рекомендация', 4.324858121453037),
#  ('стараться', 4.246224337426618),
#  ('данный', 4.163933168096644),
#  ('обычный', 4.151863796594915),
#  ('оказываться', 4.140821605646524),
#  ('нести', 4.097234009797614),
#  ('публика', 3.8923723093077327),
#  ('все-таки', 3.8923723093077327),
#  ('вначале', 3.8923723093077327),
#  ('неправильно', 3.8923723093077327),
#  ('б', 3.8923723093077327),
#  ('литр', 3.8923723093077327),
#  ('тематика', 3.8923723093077327),
#  ('откровенно', 3.8923723093077327),
#  ('доставлять', 3.8923723093077327),
#  ('натуральный', 3.8923723093077327),
#  ('марина', 3.8923723093077327),
#  ('дико', 3.8923723093077327),
#  ('неоднозначный', 3.8923723093077327),
#  ('забирать', 3.8923723093077327),
#  ('выбираться', 3.8923723093077327),
#  ('ухо', 3.8923723093077327),
#  ('привозить', 3.8923723093077327),
#  ('неудобный', 3.8923723093077327),
#  ('стекло', 3.8923723093077327),
#  ('навстречу', 3.8923723093077327),
#  ('вечный', 3.8923723093077327),
#  ('расходиться', 3.8923723093077327),
#  ('тридцать', 3.8923723093077327),
#  ('попадание', 3.8923723093077327),
#  ('навязывание', 3.8923723093077327),
#  ('ценовый', 3.8923723093077327),
#  ('образовываться', 3.8923723093077327),
#  ('отставать', 3.8923723093077327),
#  ('америка', 3.8923723093077327),
#  ('подходящий', 3.8923723093077327),
#  ('спорить', 3.8923723093077327),
#  ('присутствовать', 3.8923723093077327),
#  ('исчезать', 3.8923723093077327),
#  ('очередность', 3.8923723093077327),
#  ('вспомнить', 3.8923723093077327),
#  ('скорость', 3.8923723093077327),
#  ('разумный', 3.8923723093077327),
#  ('меняться', 3.8923723093077327),
#  ('когда-то', 3.8923723093077327),
#  ('раздавать', 3.8923723093077327),
#  ('редкость', 3.8923723093077327),
#  ('отрывать', 3.8923723093077327),
#  ('пожелать', 3.8923723093077327),
#  ('подарить', 3.8923723093077327),
#  ('вес', 3.8923723093077327),
#  ('артист', 3.8923723093077327),
#  ('концерт', 3.8923723093077327),
#  ('табличка', 3.8923723093077327),
#  ('надолго', 3.8923723093077327),
#  ('завышать', 3.8923723093077327),
#  ('прилично', 3.8923723093077327),
#  ('завоз', 3.8923723093077327),
#  ('заполнять', 3.8923723093077327),
#  ('перелагать', 3.8923723093077327),
#  ('каков', 3.8923723093077327),
#  ('отсутствовать', 3.8923723093077327),
#  ('подобие', 3.8923723093077327),
#  ('позиционировать', 3.8923723093077327),
#  ('мягко', 3.8923723093077327),
#  ('доходить', 3.8923723093077327),
#  ('кресло', 3.8923723093077327),
#  ('увольняться', 3.8923723093077327),
#  ('смущать', 3.8923723093077327),
#  ('зарегистрироваться', 3.8923723093077327),
#  ('холодильник', 3.8923723093077327),
#  ('смешивать', 3.8923723093077327),
#  ('субъективный', 3.8923723093077327),
#  ('типичный', 3.8923723093077327),
#  ('внимательно', 3.8923723093077327),
#  ('ровно', 3.8923723093077327),
#  ('размещаться', 3.8923723093077327),
#  ('резать', 3.8923723093077327),
#  ('вписываться', 3.8923723093077327),
#  ('неудачный', 3.8923723093077327),
#  ('приход', 3.8923723093077327),
#  ('отводить', 3.8923723093077327),
#  ('виноватый', 3.8923723093077327),
#  ('соседний', 3.8923723093077327),
#  ('находить', 3.816051283635032),
#  ('плюс', 3.7581525745040176),
#  ('ожидание', 3.6875106088178518),
#  ('попросить', 3.663409232289631),
#  ('точно', 3.6328808220205513),
#  ('плохой', 3.592959054745599),
#  ('отдельный', 3.550936141824598),
#  ('причем', 3.5385202811888483),
#  ('телефон', 3.5385202811888483),
#  ('написать', 3.5031350783769595),
#  ('дешевый', 3.459886497162429),
#  ('якобы', 3.459886497162429),
#  ('претензия', 3.4252876321908046),
#  ('замечать', 3.384671573311072),
#  ('вполне', 3.373389334733369),
#  ('следить', 3.3363191222637707),
#  ('судя', 3.3363191222637707),
#  ('безусловно', 3.3363191222637707),
#  ('заканчивать', 3.3363191222637707),
#  ('зеленый', 3.3363191222637707),
#  ('общий', 3.291111546081335),
#  ('смена', 3.2436435910897776),
#  ('сын', 3.2436435910897776),
#  ('рад', 3.2054830782534274),
#  ('уезжать', 3.113897847446186),
#  ('штука', 3.113897847446186),
#  ('постараться', 3.113897847446186),
#  ('наблюдать', 3.113897847446186),
#  ('чешский', 3.113897847446186),
#  ('культурный', 3.113897847446186),
#  ('проспект', 3.113897847446186),
#  ('правильно', 3.113897847446186),
#  ('название', 3.113897847446186),
#  ('явно', 3.113897847446186),
#  ('позитивный', 3.113897847446186),
#  ('интересовать', 3.113897847446186),
#  ('разный', 3.0582925287417897),
#  ('надеяться', 3.0462044159799646),
#  ('многие', 2.994132545621333),
#  ('количество', 2.9192792319808),
#  ('понятный', 2.9192792319808),
#  ('громкий', 2.9192792319808),
#  ('решать', 2.8857242982798708),
#  ('домашний', 2.876970837314411),
#  ('отдавать', 2.8680638068583293),
#  ('соответствовать', 2.8680638068583293),
#  ('простой', 2.8680638068583293),
#  ('выражать', 2.8680638068583293),
#  ('прием', 2.830816224951078),
#  ('постоянно', 2.780265935219809),
#  ('обращать', 2.747556924217223),
#  ('сей', 2.724660616515413),
#  ('во-первых', 2.724660616515413),
#  ('целое', 2.7156085878891156),
#  ('любой', 2.6799940490315537),
#  ('проводить', 2.676005962649066),
#  ('китайский', 2.663202106368449),
#  ('приглашать', 2.5949148728718217),
#  ('неожиданный', 2.5949148728718217),
#  ('четверо', 2.5949148728718217),
#  ('фаворит', 2.5949148728718217),
#  ('метро', 2.5949148728718217),
#  ('ан', 2.5949148728718217),
#  ('скажем', 2.5949148728718217),
#  ('джон', 2.5949148728718217),
#  ('воспользоваться', 2.5949148728718217),
#  ('измерение', 2.5949148728718217),
#  ('пресловутый', 2.5949148728718217),
#  ('позвонить', 2.5949148728718217),
#  ('контейнер', 2.5949148728718217),
#  ('страдать', 2.5949148728718217),
#  ('китаец', 2.5949148728718217),
#  ('дружеский', 2.5949148728718217),
#  ('угодно', 2.5949148728718217),
#  ('упоминать', 2.5949148728718217),
#  ('страх', 2.5949148728718217),
#  ('знакомство', 2.5949148728718217),
#  ('плавать', 2.5949148728718217),
#  ('таковой', 2.5949148728718217),
#  ('воздушный', 2.5949148728718217),
#  ('подряд', 2.5949148728718217),
#  ('картина', 2.5949148728718217),
#  ('выгодно', 2.5949148728718217),
#  ('видео', 2.5949148728718217),
#  ('господин', 2.5949148728718217),
#  ('оправдываться', 2.5949148728718217),
#  ('неизвестный', 2.5949148728718217),
#  ('ярко', 2.5949148728718217),
#  ('важно', 2.5949148728718217),
#  ('ездить', 2.5949148728718217),
#  ('максимум', 2.5949148728718217),
#  ('интересоваться', 2.5949148728718217),
#  ('камень', 2.5949148728718217),
#  ('голубой', 2.5949148728718217),
#  ('загрузка', 2.5949148728718217),
#  ('однозначный', 2.5949148728718217),
#  ('здоровье', 2.5949148728718217),
#  ('кто-нибудь', 2.5949148728718217),
#  ('родительский', 2.5949148728718217),
#  ('память', 2.5949148728718217),
#  ('традиция', 2.5949148728718217),
#  ('планка', 2.5949148728718217),
#  ('казус', 2.5949148728718217),
#  ('сопровождать', 2.5949148728718217),
#  ('плохо', 2.5949148728718217),
#  ('опробовать', 2.5949148728718217),
#  ('любовь', 2.5949148728718217),
#  ('отмечать', 2.570434543882465),
#  ('качество', 2.5112079414888595),
#  ('семья', 2.4911182779569487),
#  ('собирать', 2.458340405878568),
#  ('суббота', 2.458340405878568),
#  ('ставить', 2.458340405878568),
#  ('напоминать', 2.432732693317333),
#  ('узнавать', 2.395306036497066),
#  ('замечание', 2.395306036497066),
#  ('французский', 2.395306036497066),
#  ('заканчиваться', 2.395306036497066),
#  ('переживать', 2.3354233855846394),
#  ('тип', 2.3354233855846394),
#  ('воскресение', 2.3354233855846394),
#  ('черный', 2.3354233855846394),
#  ('некоторые', 2.3354233855846394),
#  ('быстрый', 2.3354233855846394),
#  ('приходиться', 2.3042844071101776),
#  ('намного', 2.224212748175847),
#  ('ориентироваться', 2.224212748175847),
#  ('ошибка', 2.224212748175847),
#  ('впервые', 2.224212748175847),
#  ('предоплата', 2.224212748175847),
#  ('уверенность', 2.224212748175847),
#  ('подавать', 2.200036522652197),
#  ('вместо', 2.1797284932123304),
#  ('во-вторых', 2.1624290607265184),
#  ('производить', 2.1624290607265184),
#  ('складываться', 2.123112168713309),
#  ('полный', 2.088590019628539),
#  ('принцип', 2.0759318982974575),
#  ('отличие', 2.0759318982974575),
#  ('знакомый', 2.03886168582786),
#  ('попадать', 2.030802943986643),
#  ('поэтому', 1.9815713574657547),
#  ('внутри', 1.9461861546538664),
#  ('ошибочный', 1.9461861546538664),
#  ('визит', 1.9461861546538664),
#  ('полезный', 1.9461861546538664),
#  ('исправлять', 1.9461861546538664),
#  ('знание', 1.9461861546538664),
#  ('английский', 1.9461861546538664),
#  ('обманывать', 1.9461861546538664),
#  ('поработать', 1.9461861546538664),
#  ('сдерживать', 1.9461861546538664),
#  ('похожий', 1.9461861546538664),
#  ('нарастать', 1.9461861546538664),
#  ('вслед', 1.9461861546538664),
#  ('тяжело', 1.9461861546538664),
#  ('недолго', 1.9461861546538664),
#  ('занимать', 1.9461861546538664),
#  ('обстоять', 1.9461861546538664),
#  ('исключительный', 1.9461861546538664),
#  ('придумывать', 1.9461861546538664),
#  ('объективно', 1.9461861546538664),
#  ('брат', 1.9461861546538664),
#  ('доставка', 1.9461861546538664),
#  ('бояться', 1.9461861546538664),
#  ('критично', 1.9461861546538664),
#  ('успех', 1.9461861546538664),
#  ('критик', 1.9461861546538664),
#  ('создаваться', 1.9461861546538664),
#  ('редкий', 1.9461861546538664),
#  ('сигарета', 1.9461861546538664),
#  ('выяснять', 1.9461861546538664),
#  ('валентин', 1.9461861546538664),
#  ('поменять', 1.9461861546538664),
#  ('опираться', 1.9461861546538664),
#  ('непонятный', 1.9461861546538664),
#  ('разговаривать', 1.9461861546538664),
#  ('медленно', 1.9461861546538664),
#  ('екатерина', 1.9461861546538664),
#  ('экономить', 1.9461861546538664),
#  ('опасение', 1.9461861546538664),
#  ('разделение', 1.9461861546538664),
#  ('повторять', 1.9461861546538664),
#  ('лес', 1.9461861546538664),
#  ('висеть', 1.9461861546538664),
#  ('ориентировать', 1.9461861546538664),
#  ('верхний', 1.9461861546538664),
#  ('присоединяться', 1.9461861546538664),
#  ('жилой', 1.9461861546538664),
#  ('научаться', 1.9461861546538664),
#  ('пятничный', 1.9461861546538664),
#  ('видный', 1.9461861546538664),
#  ('деталь', 1.9461861546538664),
#  ('переплачивать', 1.9461861546538664),
#  ('остальной', 1.8790762872520088),
#  ('вчера', 1.8683387084677117),
#  ('постоянный', 1.8683387084677117),
#  ('касаться', 1.8683387084677117),
#  ('относительно', 1.8317046161448154),
#  ('устраивать', 1.8317046161448154),
#  ('открывать', 1.8317046161448154),
#  ('поставлять', 1.8071728578928759),
#  ('наоборот', 1.7964795273727996),
#  ('равный', 1.7692601405944242),
#  ('искать', 1.7578455590422022),
#  ('го', 1.7299432485812145),
#  ('италия', 1.7299432485812145),
#  ('предупреждать', 1.7299432485812145),
#  ('татьяна', 1.7299432485812145),
#  ('ко', 1.7299432485812145),
#  ('вспоминать', 1.7299432485812145),
#  ('род', 1.7299432485812145),
#  ('токио', 1.7299432485812145),
#  ('класс', 1.7299432485812145),
#  ('реклама', 1.7299432485812145),
#  ('зона', 1.692335786655536),
#  ('предпочитать', 1.6681595611318853),
#  ('пространство', 1.6681595611318853),
#  ('район', 1.6027415391267137),
#  ('включать', 1.6027415391267137),
#  ('одновременно', 1.5569489237230931),
#  ('крайний', 1.5569489237230931),
#  ('уголь', 1.5569489237230931),
#  ('наталья', 1.5569489237230931),
#  ('определенно', 1.556948923723093),
#  ('питание', 1.556948923723093),
#  ('прибегать', 1.556948923723093),
#  ('посчитать', 1.556948923723093),
#  ('в-третьих', 1.556948923723093),
#  ('птица', 1.556948923723093),
#  ('регулярно', 1.556948923723093),
#  ('звучать', 1.556948923723093),
#  ('ведущий', 1.556948923723093),
#  ('критичный', 1.556948923723093),
#  ('разделять', 1.556948923723093),
#  ('наполнять', 1.556948923723093),
#  ('реально', 1.556948923723093),
#  ('добираться', 1.556948923723093),
#  ('существование', 1.556948923723093),
#  ('удивительно', 1.556948923723093),
#  ('возражение', 1.556948923723093),
#  ('выгодный', 1.556948923723093),
#  ('ограничиваться', 1.556948923723093),
#  ('заметный', 1.556948923723093),
#  ('стандартный', 1.556948923723093),
#  ('какой-то', 1.513700342508563),
#  ('цена', 1.510472836447777),
#  ('ожидать', 1.4906957780327488),
#  ('наличие', 1.482808498783898),
#  ('отвечать', 1.4727895224407639),
#  ('купить', 1.4596396159904),
#  ('очередной', 1.4596396159904),
#  ('лето', 1.4596396159904),
#  ('многий', 1.4298510523987589),
#  ('практически', 1.4298510523987589),
#  ('появляться', 1.4154081124755393),
#  ('длительный', 1.415408112475539),
#  ('желание', 1.415408112475539),
#  ('вынести', 1.415408112475539),
#  ('разница', 1.415408112475539),
#  ('средний', 1.415408112475539),
#  ('столь', 1.415408112475539),
#  ('протяжение', 1.415408112475539),
#  ('случаться', 1.415408112475539),
#  ('труд', 1.415408112475539),
#  ('разрешать', 1.3737784621086115),
#  ('многое', 1.3737784621086115),
#  ('сильно', 1.3737784621086115),
#  ('итог', 1.3657446699325377),
#  ('удаваться', 1.35924112388524),
#  ('уровень', 1.35924112388524),
#  ('больший', 1.3538686293244286),
#  ('февраль', 1.3538686293244286),
#  ('просьба', 1.3421973480371492),
#  ('просить', 1.3345276489055085),
#  ('восточный', 1.3291027397636161),
#  ('высокий', 1.3174183200733864),
#  ('пятница', 1.3174183200733864),
#  ('прочий', 1.2974574364359108),
#  ('расплачиваться', 1.2974574364359108),
#  ('сетовать', 1.2974574364359108),
#  ('непонятно', 1.2974574364359108),
#  ('предварительно', 1.2974574364359108),
#  ('преимущество', 1.2974574364359108),
#  ('исполнение', 1.2974574364359108),
#  ('нью-йорк', 1.2974574364359108),
#  ('оптимальный', 1.2974574364359108),
#  ('специфический', 1.2974574364359108),
#  ('немало', 1.2974574364359108),
#  ('счесть', 1.2974574364359108),
#  ('полноценный', 1.2974574364359108),
#  ('легко', 1.2974574364359108),
#  ('сопровождаться', 1.2974574364359108),
#  ('оттуда', 1.2974574364359108),
#  ('реальность', 1.2974574364359108),
#  ('торопиться', 1.2974574364359108),
#  ('делиться', 1.2974574364359108),
#  ('дух', 1.2974574364359108),
#  ('мелкий', 1.2974574364359108),
#  ('страница', 1.2974574364359108),
#  ('яркий', 1.2974574364359108),
#  ('привыкать', 1.2974574364359108),
#  ('секрет', 1.2974574364359108),
#  ('естественный', 1.2974574364359108),
#  ('называться', 1.2974574364359108),
#  ('настоящий', 1.2623910192349403),
#  ('проверять', 1.2455591389784744),
#  ('либо', 1.2455591389784744),
#  ('гораздо', 1.2455591389784744),
#  ('встречаться', 1.229170202939284),
#  ('запланировать', 1.229170202939284),
#  ('декабрь', 1.229170202939284),
#  ('встреча', 1.1976530182485332),
#  ('формат', 1.197653018248533),
#  ('показывать', 1.197653018248533),
#  ('отказывать', 1.197653018248533),
#  ('несмотря', 1.1750557914891266),
#  ('проходить', 1.171897039361468),
#  ('исключение', 1.1677116927923197),
#  ('евгений', 1.1677116927923197),
#  ('счет', 1.1423266559924867),
#  ('выходить', 1.1352752568814222),
#  ('коллега', 1.1121063740879238),
#  ('отсутствие', 1.1121063740879238),
#  ('долгий', 1.1121063740879238),
#  ('петербург', 1.1121063740879238),
#  ('положительно', 1.1121063740879236),
#  ('виталий', 1.1121063740879236),
#  ('соблюдать', 1.1121063740879236),
#  ('современный', 1.1121063740879236),
#  ('заслуживать', 1.1121063740879236),
#  ('возвращаться', 1.1121063740879236),
#  ('давность', 1.1121063740879236),
#  ('описывать', 1.1121063740879236),
#  ('дата', 1.1121063740879236),
#  ('обратно', 1.1121063740879236),
#  ('оговаривать', 1.1121063740879236),
#  ('выступление', 1.1121063740879236),
#  ('вовсе', 1.1121063740879236),
#  ('таков', 1.1121063740879236),
#  ('вплоть', 1.1121063740879236),
#  ('выясняться', 1.1121063740879236),
#  ('разбираться', 1.1121063740879236),
#  ('светлана', 1.1121063740879236),
#  ('начинать', 1.1000182613260985),
#  ('открытие', 1.0737578784297193),
#  ('специальный', 1.0615560843566545),
#  ('момент', 1.0615560843566545),
#  ('учитывать', 1.0555585923546391),
#  ('вызывать', 1.0379659491487288),
#  ('напротив', 1.0379659491487288),
#  ('правильный', 1.0379659491487288),
#  ('следующий', 1.0379659491487288),
#  ('елена', 1.0379659491487288),
#  ('никак', 1.0379659491487288),
#  ('вывод', 1.0379659491487288),
#  ('состав', 1.0209501139167825),
#  ('предлагать', 1.0133987077487587),
#  ('центр', 0.9998754556019864),
#  ('разговор', 0.9730930773269332),
#  ('фирма', 0.9730930773269332),
#  ('масса', 0.9730930773269332),
#  ('переставать', 0.9730930773269332),
#  ('продлиться', 0.9730930773269332),
#  ('март', 0.9730930773269332),
#  ('заставлять', 0.9730930773269332),
#  ('команда', 0.9730930773269332),
#  ('богатый', 0.9730930773269332),
#  ('обещать', 0.9730930773269332),
#  ('поздно', 0.9730930773269332),
#  ('сдавать', 0.9730930773269332),
#  ('критиковать', 0.9730930773269332),
#  ('д', 0.9730930773269332),
#  ('точный', 0.9730930773269332),
#  ('летать', 0.9730930773269332),
#  ('спустя', 0.9730930773269332),
#  ('опасаться', 0.9730930773269332),
#  ('пусть', 0.9730930773269332),
#  ('знак', 0.9730930773269332),
#  ('предыдущий', 0.9341693542338558),
#  ('предел', 0.9341693542338558),
#  ('захотеть', 0.9158523080724077),
#  ('трудно', 0.9158523080724077),
#  ('европейский', 0.9025790862162858),
#  ('выглядеть', 0.8982397636863998),
#  ('успешно', 0.8649716242906073),
#  ('благодаря', 0.8649716242906073),
#  ('решаться', 0.8649716242906073),
#  ('шок', 0.8649716242906073),
#  ('трасса', 0.8649716242906073),
#  ('въезд', 0.8649716242906073),
#  ('закрывать', 0.8649716242906073),
#  ('опытный', 0.8649716242906073),
#  ('обыкновенный', 0.8649716242906073),
#  ('скромный', 0.8649716242906073),
#  ('площадь', 0.8649716242906073),
#  ('сомнительный', 0.8649716242906073),
#  ('заменять', 0.8649716242906073),
#  ('последующий', 0.8649716242906073),
#  ('оценивать', 0.8649716242906073),
#  ('множество', 0.8649716242906073),
#  ('зависеть', 0.8415940128232935),
#  ('оценка', 0.8383571127739733),
#  ('подобный', 0.8340797805659427),
#  ('изменяться', 0.8340797805659427),
#  ('вновь', 0.8194468019595226),
#  ('собираться', 0.8194468019595226),
#  ...]

# %%
#костыль, преобразующий сортированные списки обратно в словарь
weirdness_sorted_dict = {}
for el in sorted_by_weirdness:
    weirdness_sorted_dict[el[0]] = el[1]
    

loglikelihood_sorted_dict = {}
for el in sorted_by_loglikelihood:
    loglikelihood_sorted_dict[el[0]] = el[1]

# %%
#feel up the dataframe
data = {}
words = []
word_type = []
countspec = []
countref = []
loglikelihood = []
rang = []
weirdness = []
rang_weirdness = []

for n, tup in enumerate(sorted_by_loglikelihood):
    if n <= 10:
        word = tup[0]
        words.append(word)
        word_type.append('тематическое')
        countspec.append(frequencySpec[word]/len(Spec))
        countref.append(frequencyRef[word]/len(Ref))
        loglikelihood.append(loglikelihood_total[word])
        rang.append(n)
        weirdness.append(weirdness_total[word])
        rang_weirdness.append(sorted_by_weirdness.index((word, weirdness_total[word])))
        
    else:
        break

# %%
#feel up the dataframe
sorted_by_loglikelihood_before = sorted_by_loglikelihood
sorted_by_loglikelihood = sorted(loglikelihood_total.items(), key=lambda x: float(x[1]))


for n, tup in enumerate(sorted_by_loglikelihood):
    if n <= 10:
        word = tup[0]
        words.append(word)
        word_type.append('общеупотребительное')
        countspec.append(frequencySpec[word]/len(Spec))
        countref.append(frequencyRef[word]/len(Ref))
        loglikelihood.append(loglikelihood_total[word])
        rang.append(sorted_by_loglikelihood_before.index((word, loglikelihood_total[word])))
        weirdness.append(weirdness_total[word])
        rang_weirdness.append(sorted_by_weirdness.index((word, weirdness_total[word])))
    else:
        break

# %%
#draw the table
data = collections.OrderedDict(data)
data['word'] = words
data['Тип'] = word_type
data['CountSpecC'] = countspec
data['CountRefC'] = countref
data['LogLikelihood'] = loglikelihood
data['Ранг loglikelihood'] = rang
data['Weirdness'] = weirdness
data['Ранг weirdness'] = rang_weirdness

pandas.DataFrame(data = data)
# Out:
#             word                  Тип  CountSpecC  CountRefC  LogLikelihood  \
# 0       ресторан         тематическое    0.021226   0.000010   1.216875e+03
# 1    понравиться         тематическое    0.011475   0.000019   6.440513e+02
# 2     заказывать         тематическое    0.010350   0.000029   5.714411e+02
# 3          блюдо         тематическое    0.010200   0.000019   5.706366e+02
# 4           меню         тематическое    0.008025   0.000010   4.539123e+02
# 5            еда         тематическое    0.006900   0.000010   3.890224e+02
# 6      заведение         тематическое    0.006750   0.000010   3.803740e+02
# 7      приносить         тематическое    0.008475   0.000222   3.730411e+02
# 8   обслуживание         тематическое    0.008325   0.000241   3.586696e+02
# 9            зал         тематическое    0.006450   0.000067   3.257777e+02
# 10        порция         тематическое    0.004200   0.000010   2.335511e+02
# 11         центр  общеупотребительное    0.001050   0.001050   1.924712e-07
# 12         масса  общеупотребительное    0.000075   0.000077   6.659864e-04
# 13    продлиться  общеупотребительное    0.000075   0.000077   6.659864e-04
# 14       команда  общеупотребительное    0.000075   0.000077   6.659864e-04
# 15       богатый  общеупотребительное    0.000075   0.000077   6.659864e-04
# 16       сдавать  общеупотребительное    0.000075   0.000077   6.659864e-04
# 17   критиковать  общеупотребительное    0.000075   0.000077   6.659864e-04
# 18        точный  общеупотребительное    0.000075   0.000077   6.659864e-04
# 19        летать  общеупотребительное    0.000075   0.000077   6.659864e-04
# 20        спустя  общеупотребительное    0.000075   0.000077   6.659864e-04
# 21         пусть  общеупотребительное    0.000075   0.000077   6.659864e-04
#
#     Ранг loglikelihood    Weirdness  Ранг weirdness
# 0                    0  2203.082727               0
# 1                    1   595.532963               4
# 2                    2   358.098252               8
# 3                    3   529.362634               5
# 4                    4   832.967674               1
# 5                    5   716.196505               2
# 6                    6   700.627016               3
# 7                    7    38.246789              86
# 8                    8    34.564266              89
# 9                    9    95.641148              22
# 10                  10   435.945699               6
# 11                1345     0.999875             951
# 12                1334     0.973093             954
# 13                1335     0.973093             956
# 14                1336     0.973093             959
# 15                1337     0.973093             960
# 16                1338     0.973093             963
# 17                1339     0.973093             964
# 18                1340     0.973093             966
# 19                1341     0.973093             967
# 20                1342     0.973093             968
# 21                1343     0.973093             970
